# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)           # we mount the google drive at /content/drive
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/repos
# Out:
# /content/drive/MyDrive/repos

# %%
# %cd TFM_food_recognition/
# Out:
# /content/drive/My Drive/repos/TFM_food_recognition

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	Untitled0.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 6 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.
# From https://github.com/utxu/TFM_food_recognition
#    c079c7c..9901167  main       -> origin/main
# Updating c079c7c..9901167
# Fast-forward
#  clone_repository_on_drive.ipynb | 439 ++++++++++++++++++++++
#  colab_vgg16_FE_noaugmen.ipynb   | 790 ++++++++++++++++++++++++++++++++++++++++
#  2 files changed, 1229 insertions(+)
#  create mode 100644 clone_repository_on_drive.ipynb
#  create mode 100644 colab_vgg16_FE_noaugmen.ipynb

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	Untitled0.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
